# %%
import pandas as pd

# %%
data = pd.read_csv('tesla_ford_bmw_volkswagen_hyundai_full.csv')
data.head()
# Out:
#                        Price     Tesla_Adj Close         Tesla_Close  \
# 0                     Ticker          Tesla_TSLA          Tesla_TSLA
# 1                       Date                 NaN                 NaN
# 2  2019-01-02 00:00:00+00:00  20.674667358398438  20.674667358398438
# 3  2019-01-03 00:00:00+00:00   20.02400016784668   20.02400016784668
# 4  2019-01-04 00:00:00+00:00  21.179332733154297  21.179332733154297
#
#            Tesla_High           Tesla_Low          Tesla_Open Tesla_Volume  \
# 0          Tesla_TSLA          Tesla_TSLA          Tesla_TSLA   Tesla_TSLA
# 1                 NaN                 NaN                 NaN          NaN
# 2    21.0086669921875  19.920000076293945  20.406667709350586    174879000
# 3  20.626667022705078  19.825332641601562   20.46666717529297    104478000
# 4  21.200000762939453   20.18199920654297  20.399999618530273    110911500
#
#       Ford_Adj Close         Ford_Close          Ford_High  ...  \
# 0             Ford_F             Ford_F             Ford_F  ...
# 1                NaN                NaN                NaN  ...
# 2  5.936494827270508  7.900000095367432  8.020000457763672  ...
# 3  5.846320629119873   7.78000020980835  7.989999771118164  ...
# 4  6.071756839752197  8.079999923706055  8.119999885559082  ...
#
#       Volkswagen_High      Volkswagen_Low     Volkswagen_Open  \
# 0    Volkswagen_VWAGY    Volkswagen_VWAGY    Volkswagen_VWAGY
# 1                 NaN                 NaN                 NaN
# 2  15.510000228881836  15.295000076293945    15.3149995803833
# 3                15.5  15.369999885559082   15.40999984741211
# 4  16.084999084472656  15.729999542236328  15.760000228881836
#
#   Volkswagen_Volume  Hyundai_Adj Close  Hyundai_Close   Hyundai_High  \
# 0  Volkswagen_VWAGY      Hyundai_HYMTF  Hyundai_HYMTF  Hyundai_HYMTF
# 1               NaN                NaN            NaN            NaN
# 2             94200  23.85686492919922          25.25          25.25
# 3             90100  23.85686492919922          25.25          25.25
# 4            106500  23.85686492919922          25.25          25.25
#
#      Hyundai_Low   Hyundai_Open Hyundai_Volume
# 0  Hyundai_HYMTF  Hyundai_HYMTF  Hyundai_HYMTF
# 1            NaN            NaN            NaN
# 2          25.25          25.25              0
# 3          25.25          25.25            100
# 4          25.25          25.25              0
#
# [5 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['Price', 'Tesla_Adj Close', 'Tesla_Close', 'Tesla_High', 'Tesla_Low',
#        'Tesla_Open', 'Tesla_Volume', 'Ford_Adj Close', 'Ford_Close',
#        'Ford_High', 'Ford_Low', 'Ford_Open', 'Ford_Volume', 'BMW_Adj Close',
#        'BMW_Close', 'BMW_High', 'BMW_Low', 'BMW_Open', 'BMW_Volume',
#        'Volkswagen_Adj Close', 'Volkswagen_Close', 'Volkswagen_High',
#        'Volkswagen_Low', 'Volkswagen_Open', 'Volkswagen_Volume',
#        'Hyundai_Adj Close', 'Hyundai_Close', 'Hyundai_High', 'Hyundai_Low',
#        'Hyundai_Open', 'Hyundai_Volume'],
#       dtype='object')

# %%
data.rename(columns={'Price': 'Date',},inplace=True)

# %%
data.drop([0, 1], inplace=True)
data.head()
# Out:
#                         Date     Tesla_Adj Close         Tesla_Close  \
# 2  2019-01-02 00:00:00+00:00  20.674667358398438  20.674667358398438
# 3  2019-01-03 00:00:00+00:00   20.02400016784668   20.02400016784668
# 4  2019-01-04 00:00:00+00:00  21.179332733154297  21.179332733154297
# 5  2019-01-07 00:00:00+00:00   22.33066749572754   22.33066749572754
# 6  2019-01-08 00:00:00+00:00  22.356666564941406  22.356666564941406
#
#            Tesla_High           Tesla_Low          Tesla_Open Tesla_Volume  \
# 2    21.0086669921875  19.920000076293945  20.406667709350586    174879000
# 3  20.626667022705078  19.825332641601562   20.46666717529297    104478000
# 4  21.200000762939453   20.18199920654297  20.399999618530273    110911500
# 5   22.44933319091797  21.183332443237305  21.447999954223633    113268000
# 6   22.93400001525879  21.801332473754883  22.797332763671875    105127500
#
#       Ford_Adj Close         Ford_Close          Ford_High  ...  \
# 2  5.936494827270508  7.900000095367432  8.020000457763672  ...
# 3  5.846320629119873   7.78000020980835  7.989999771118164  ...
# 4  6.071756839752197  8.079999923706055  8.119999885559082  ...
# 5  6.229562759399414  8.289999961853027  8.369999885559082  ...
# 6  6.289679050445557  8.369999885559082  8.539999961853027  ...
#
#       Volkswagen_High      Volkswagen_Low     Volkswagen_Open  \
# 2  15.510000228881836  15.295000076293945    15.3149995803833
# 3                15.5  15.369999885559082   15.40999984741211
# 4  16.084999084472656  15.729999542236328  15.760000228881836
# 5  16.350000381469727  16.170000076293945  16.264999389648438
# 6   16.63800048828125    16.3799991607666  16.610000610351562
#
#   Volkswagen_Volume  Hyundai_Adj Close Hyundai_Close Hyundai_High Hyundai_Low  \
# 2             94200  23.85686492919922         25.25        25.25       25.25
# 3             90100  23.85686492919922         25.25        25.25       25.25
# 4            106500  23.85686492919922         25.25        25.25       25.25
# 5            158100  23.85686492919922         25.25        25.25       25.25
# 6            106900  23.85686492919922         25.25        25.25       25.25
#
#   Hyundai_Open Hyundai_Volume
# 2        25.25              0
# 3        25.25            100
# 4        25.25              0
# 5        25.25            500
# 6        25.25            100
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (1469, 31)

# %%
data.dtypes
# Out:
# Date                    object
# Tesla_Adj Close         object
# Tesla_Close             object
# Tesla_High              object
# Tesla_Low               object
# Tesla_Open              object
# Tesla_Volume            object
# Ford_Adj Close          object
# Ford_Close              object
# Ford_High               object
# Ford_Low                object
# Ford_Open               object
# Ford_Volume             object
# BMW_Adj Close           object
# BMW_Close               object
# BMW_High                object
# BMW_Low                 object
# BMW_Open                object
# BMW_Volume              object
# Volkswagen_Adj Close    object
# Volkswagen_Close        object
# Volkswagen_High         object
# Volkswagen_Low          object
# Volkswagen_Open         object
# Volkswagen_Volume       object
# Hyundai_Adj Close       object
# Hyundai_Close           object
# Hyundai_High            object
# Hyundai_Low             object
# Hyundai_Open            object
# Hyundai_Volume          object
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date'])

data['Date'] = data['Date'].dt.date

data.head()
# Out:
#          Date     Tesla_Adj Close         Tesla_Close          Tesla_High  \
# 2  2019-01-02  20.674667358398438  20.674667358398438    21.0086669921875
# 3  2019-01-03   20.02400016784668   20.02400016784668  20.626667022705078
# 4  2019-01-04  21.179332733154297  21.179332733154297  21.200000762939453
# 5  2019-01-07   22.33066749572754   22.33066749572754   22.44933319091797
# 6  2019-01-08  22.356666564941406  22.356666564941406   22.93400001525879
#
#             Tesla_Low          Tesla_Open Tesla_Volume     Ford_Adj Close  \
# 2  19.920000076293945  20.406667709350586    174879000  5.936494827270508
# 3  19.825332641601562   20.46666717529297    104478000  5.846320629119873
# 4   20.18199920654297  20.399999618530273    110911500  6.071756839752197
# 5  21.183332443237305  21.447999954223633    113268000  6.229562759399414
# 6  21.801332473754883  22.797332763671875    105127500  6.289679050445557
#
#           Ford_Close          Ford_High  ...     Volkswagen_High  \
# 2  7.900000095367432  8.020000457763672  ...  15.510000228881836
# 3   7.78000020980835  7.989999771118164  ...                15.5
# 4  8.079999923706055  8.119999885559082  ...  16.084999084472656
# 5  8.289999961853027  8.369999885559082  ...  16.350000381469727
# 6  8.369999885559082  8.539999961853027  ...   16.63800048828125
#
#        Volkswagen_Low     Volkswagen_Open Volkswagen_Volume  \
# 2  15.295000076293945    15.3149995803833             94200
# 3  15.369999885559082   15.40999984741211             90100
# 4  15.729999542236328  15.760000228881836            106500
# 5  16.170000076293945  16.264999389648438            158100
# 6    16.3799991607666  16.610000610351562            106900
#
#    Hyundai_Adj Close Hyundai_Close Hyundai_High Hyundai_Low Hyundai_Open  \
# 2  23.85686492919922         25.25        25.25       25.25        25.25
# 3  23.85686492919922         25.25        25.25       25.25        25.25
# 4  23.85686492919922         25.25        25.25       25.25        25.25
# 5  23.85686492919922         25.25        25.25       25.25        25.25
# 6  23.85686492919922         25.25        25.25       25.25        25.25
#
#   Hyundai_Volume
# 2              0
# 3            100
# 4              0
# 5            500
# 6            100
#
# [5 rows x 31 columns]

# %%
numeric_columns = [
    'Tesla_Adj Close', 'Tesla_Close', 'Tesla_High', 'Tesla_Low',
       'Tesla_Open', 'Tesla_Volume', 'Ford_Adj Close', 'Ford_Close',
       'Ford_High', 'Ford_Low', 'Ford_Open', 'Ford_Volume', 'BMW_Adj Close',
       'BMW_Close', 'BMW_High', 'BMW_Low', 'BMW_Open', 'BMW_Volume',
       'Volkswagen_Adj Close', 'Volkswagen_Close', 'Volkswagen_High',
       'Volkswagen_Low', 'Volkswagen_Open', 'Volkswagen_Volume',
       'Hyundai_Adj Close', 'Hyundai_Close', 'Hyundai_High', 'Hyundai_Low',
       'Hyundai_Open', 'Hyundai_Volume'
]

for column in numeric_columns:
    data[column] = pd.to_numeric(data[column], errors="coerce")

# %%
data[numeric_columns] = data[numeric_columns].round(2)
data.head()
# Out:
#          Date  Tesla_Adj Close  Tesla_Close  Tesla_High  Tesla_Low  \
# 2  2019-01-02            20.67        20.67       21.01      19.92
# 3  2019-01-03            20.02        20.02       20.63      19.83
# 4  2019-01-04            21.18        21.18       21.20      20.18
# 5  2019-01-07            22.33        22.33       22.45      21.18
# 6  2019-01-08            22.36        22.36       22.93      21.80
#
#    Tesla_Open  Tesla_Volume  Ford_Adj Close  Ford_Close  Ford_High  ...  \
# 2       20.41     174879000            5.94        7.90       8.02  ...
# 3       20.47     104478000            5.85        7.78       7.99  ...
# 4       20.40     110911500            6.07        8.08       8.12  ...
# 5       21.45     113268000            6.23        8.29       8.37  ...
# 6       22.80     105127500            6.29        8.37       8.54  ...
#
#    Volkswagen_High  Volkswagen_Low  Volkswagen_Open  Volkswagen_Volume  \
# 2            15.51           15.30            15.31              94200
# 3            15.50           15.37            15.41              90100
# 4            16.08           15.73            15.76             106500
# 5            16.35           16.17            16.26             158100
# 6            16.64           16.38            16.61             106900
#
#    Hyundai_Adj Close  Hyundai_Close  Hyundai_High  Hyundai_Low  Hyundai_Open  \
# 2              23.86          25.25         25.25        25.25         25.25
# 3              23.86          25.25         25.25        25.25         25.25
# 4              23.86          25.25         25.25        25.25         25.25
# 5              23.86          25.25         25.25        25.25         25.25
# 6              23.86          25.25         25.25        25.25         25.25
#
#    Hyundai_Volume
# 2               0
# 3             100
# 4               0
# 5             500
# 6             100
#
# [5 rows x 31 columns]

# %%
data.dtypes
# Out:
# Date                     object
# Tesla_Adj Close         float64
# Tesla_Close             float64
# Tesla_High              float64
# Tesla_Low               float64
# Tesla_Open              float64
# Tesla_Volume              int64
# Ford_Adj Close          float64
# Ford_Close              float64
# Ford_High               float64
# Ford_Low                float64
# Ford_Open               float64
# Ford_Volume               int64
# BMW_Adj Close           float64
# BMW_Close               float64
# BMW_High                float64
# BMW_Low                 float64
# BMW_Open                float64
# BMW_Volume                int64
# Volkswagen_Adj Close    float64
# Volkswagen_Close        float64
# Volkswagen_High         float64
# Volkswagen_Low          float64
# Volkswagen_Open         float64
# Volkswagen_Volume         int64
# Hyundai_Adj Close       float64
# Hyundai_Close           float64
# Hyundai_High            float64
# Hyundai_Low             float64
# Hyundai_Open            float64
# Hyundai_Volume            int64
# dtype: object

# %%
data["Date"] = pd.to_datetime(data["Date"], errors='coerce')

# %%
data.dtypes
# Out:
# Date                    datetime64[ns]
# Tesla_Adj Close                float64
# Tesla_Close                    float64
# Tesla_High                     float64
# Tesla_Low                      float64
# Tesla_Open                     float64
# Tesla_Volume                     int64
# Ford_Adj Close                 float64
# Ford_Close                     float64
# Ford_High                      float64
# Ford_Low                       float64
# Ford_Open                      float64
# Ford_Volume                      int64
# BMW_Adj Close                  float64
# BMW_Close                      float64
# BMW_High                       float64
# BMW_Low                        float64
# BMW_Open                       float64
# BMW_Volume                       int64
# Volkswagen_Adj Close           float64
# Volkswagen_Close               float64
# Volkswagen_High                float64
# Volkswagen_Low                 float64
# Volkswagen_Open                float64
# Volkswagen_Volume                int64
# Hyundai_Adj Close              float64
# Hyundai_Close                  float64
# Hyundai_High                   float64
# Hyundai_Low                    float64
# Hyundai_Open                   float64
# Hyundai_Volume                   int64
# dtype: object

# %%
data.set_index("Date", inplace=True)

# %%
data.isna().sum()
# Out:
# Tesla_Adj Close         0
# Tesla_Close             0
# Tesla_High              0
# Tesla_Low               0
# Tesla_Open              0
# Tesla_Volume            0
# Ford_Adj Close          0
# Ford_Close              0
# Ford_High               0
# Ford_Low                0
# Ford_Open               0
# Ford_Volume             0
# BMW_Adj Close           0
# BMW_Close               0
# BMW_High                0
# BMW_Low                 0
# BMW_Open                0
# BMW_Volume              0
# Volkswagen_Adj Close    0
# Volkswagen_Close        0
# Volkswagen_High         0
# Volkswagen_Low          0
# Volkswagen_Open         0
# Volkswagen_Volume       0
# Hyundai_Adj Close       0
# Hyundai_Close           0
# Hyundai_High            0
# Hyundai_Low             0
# Hyundai_Open            0
# Hyundai_Volume          0
# dtype: int64

# %%
data.to_csv("clean_data.csv")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6))
plt.plot(data["Tesla_Close"], label="Tesla Close")
plt.plot(data["Ford_Close"], label="Ford Close")
plt.plot(data["BMW_Close"], label="BMW Close")
plt.plot(data["Volkswagen_Close"], label="Volkswagen Close")
plt.plot(data["Hyundai_Close"], label="Hyundai Close")
plt.title("Tesla vs Ford vs BMW vs Volkswagen vs Hyundai : Stock Closing Prices")
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %% [markdown]
# # Tesla

# %%
plt.figure(figsize=(15, 8))
plt.plot(data.index, data["Tesla_Close"], label="TSLA Close", alpha=0.7)
plt.plot(data.index, data["Tesla_Adj Close"], label="TSLA Adjusted Close", alpha=0.7)
plt.plot(data.index, data["Tesla_Open"], label="TSLA Open", alpha=0.7,linestyle='--')
plt.title("Tesla Stock: Close vs Open vs Adjusted Close Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.plot(data.index, data["Ford_Close"], label="Ford Close", alpha=0.7)
plt.plot(data.index, data["Ford_Adj Close"], label="Ford Adjusted Close", alpha=0.7)
plt.plot(data.index, data["Ford_Open"], label="Ford Open", alpha=0.7,linestyle='--')
plt.title("Ford Stock: Close vs Open vs Adjusted Close Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.plot(data.index, data["BMW_Close"], label="BMW Close", alpha=0.7)
plt.plot(data.index, data["BMW_Adj Close"], label="BMW Adjusted Close", alpha=0.7)
plt.plot(data.index, data["BMW_Open"], label="BMW Open", alpha=0.7,linestyle='--')
plt.title("BMW Stock: Close vs Open vs Adjusted Close Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.plot(data.index, data["Volkswagen_Close"], label="Volkswagen Close", alpha=0.7)
plt.plot(data.index, data["Volkswagen_Adj Close"], label="Volkswagen Adjusted Close", alpha=0.7)
plt.plot(data.index, data["Volkswagen_Open"], label="Volkswagen Open", alpha=0.7,linestyle='--')
plt.title("Volkswagen Stock: Close vs Open vs Adjusted Close Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 8))
plt.plot(data.index, data["Hyundai_Close"], label="Hyundai Close", alpha=0.7)
plt.plot(data.index, data["Hyundai_Adj Close"], label="Hyundai Adjusted Close", alpha=0.7)
plt.plot(data.index, data["Hyundai_Open"], label="Hyundai Open", alpha=0.7,linestyle='--')
plt.title("Hyundai Stock: Close vs Open vs Adjusted Close Prices")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
volume_columns = [col for col in data.columns if "Volume" in col]
monthly_volume = data[volume_columns].resample('M').mean()

monthly_volume.plot(kind='bar', figsize=(30, 15), width=0.8)
plt.title("Monthly Average Trading Volume", fontsize=16)
plt.xlabel("Month", fontsize=14)
plt.ylabel("Average Volume", fontsize=14)
plt.legend(volume_columns, title="Companies", fontsize=12)
plt.xticks(rotation=45, fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ILHAM\AppData\Local\Temp\ipykernel_12464\3706678749.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_volume = data[volume_columns].resample('M').mean()

# %%
import seaborn as sns
close_columns = [col for col in data.columns if "Open" in col]
close_prices = data[close_columns]

correlation_matrix = close_prices.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True,
            xticklabels=close_columns, yticklabels=close_columns)
plt.title("Correlation Between Opening Prices of Companies", fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data[['Tesla_Close', "Ford_Close", "BMW_Close", "Volkswagen_Close","Hyundai_Close"]])

# %%
def create_sequences(data, time_steps=60):
    X = []
    y = []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

# %%
X, y = create_sequences(scaled_data)

# %%
X.shape
# Out:
# (1409, 60, 5)

# %%
y.shape
# Out:
# (1409, 5)

# %%
train_size = int(len(X) * 0.9)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint


model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(60,5)))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(units=5))

model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, verbose=1)

history = model.fit(X_train, y_train, epochs=50, batch_size=32,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping, model_checkpoint],
                    verbose=1)

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0870
# Epoch 1: val_loss improved from inf to 0.03051, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - loss: 0.0849 - val_loss: 0.0305
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0146
# Epoch 2: val_loss improved from 0.03051 to 0.01896, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 0.0146 - val_loss: 0.0190
# Epoch 3/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0095
# Epoch 3: val_loss improved from 0.01896 to 0.01471, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0095 - val_loss: 0.0147
# Epoch 4/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0085
# Epoch 4: val_loss improved from 0.01471 to 0.01314, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.0085 - val_loss: 0.0131
# Epoch 5/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0073
# Epoch 5: val_loss improved from 0.01314 to 0.00944, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0073 - val_loss: 0.0094
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0076
# Epoch 6: val_loss improved from 0.00944 to 0.00707, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0064
# Epoch 7: val_loss did not improve from 0.00707
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 0.0064 - val_loss: 0.0077
# Epoch 8/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0057
# Epoch 8: val_loss improved from 0.00707 to 0.00598, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0057
# Epoch 9: val_loss improved from 0.00598 to 0.00373, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0051
# Epoch 10: val_loss improved from 0.00373 to 0.00342, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0051 - val_loss: 0.0034
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0048
# Epoch 11: val_loss did not improve from 0.00342
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0046
# Epoch 12: val_loss did not improve from 0.00342
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0046 - val_loss: 0.0038
# Epoch 13/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0051
# Epoch 13: val_loss improved from 0.00342 to 0.00319, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0051 - val_loss: 0.0032
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0043
# Epoch 14: val_loss improved from 0.00319 to 0.00308, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0043 - val_loss: 0.0031
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0046
# Epoch 15: val_loss improved from 0.00308 to 0.00306, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0046 - val_loss: 0.0031
# Epoch 16/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0043
# Epoch 16: val_loss did not improve from 0.00306
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0043 - val_loss: 0.0034
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0042
# Epoch 17: val_loss did not improve from 0.00306
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0039
# Epoch 18: val_loss improved from 0.00306 to 0.00257, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 0.0039 - val_loss: 0.0026
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0043
# Epoch 19: val_loss did not improve from 0.00257
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0043 - val_loss: 0.0033
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0040
# Epoch 20: val_loss did not improve from 0.00257
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0040 - val_loss: 0.0029
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0038
# Epoch 21: val_loss did not improve from 0.00257
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0038 - val_loss: 0.0027
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0036
# Epoch 22: val_loss did not improve from 0.00257
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 23/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0035
# Epoch 23: val_loss improved from 0.00257 to 0.00256, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 24/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0035
# Epoch 24: val_loss did not improve from 0.00256
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 25/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0035
# Epoch 25: val_loss improved from 0.00256 to 0.00244, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0036
# Epoch 26: val_loss did not improve from 0.00244
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 27/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0034
# Epoch 27: val_loss improved from 0.00244 to 0.00227, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0034
# Epoch 28: val_loss improved from 0.00227 to 0.00210, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 29/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0033
# Epoch 29: val_loss did not improve from 0.00210
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029
# Epoch 30: val_loss improved from 0.00210 to 0.00179, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 31/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0036
# Epoch 31: val_loss did not improve from 0.00179
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0032
# Epoch 32: val_loss did not improve from 0.00179
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 33/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0032
# Epoch 33: val_loss did not improve from 0.00179
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 34/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0030
# Epoch 34: val_loss did not improve from 0.00179
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 35/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0032
# Epoch 35: val_loss did not improve from 0.00179
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0030
# Epoch 36: val_loss did not improve from 0.00179
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0029
# Epoch 37: val_loss improved from 0.00179 to 0.00172, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - loss: 0.0029 - val_loss: 0.0017
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0028
# Epoch 38: val_loss did not improve from 0.00172
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0027
# Epoch 39: val_loss did not improve from 0.00172
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 40/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0028
# Epoch 40: val_loss did not improve from 0.00172
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0028 - val_loss: 0.0017
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0027
# Epoch 41: val_loss did not improve from 0.00172
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0028
# Epoch 42: val_loss improved from 0.00172 to 0.00150, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0025
# Epoch 43: val_loss did not improve from 0.00150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0025
# Epoch 44: val_loss did not improve from 0.00150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029
# Epoch 45: val_loss did not improve from 0.00150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0027
# Epoch 46: val_loss did not improve from 0.00150
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0028
# Epoch 47: val_loss improved from 0.00150 to 0.00141, saving model to best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 48/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0026
# Epoch 48: val_loss did not improve from 0.00141
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 49/50
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0027
# Epoch 49: val_loss did not improve from 0.00141
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0025
# Epoch 50: val_loss did not improve from 0.00141
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0025 - val_loss: 0.0018
# Restoring model weights from the end of the best epoch: 47.

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,root_mean_squared_error

y_pred = model.predict(X_test)

y_train_actual = scaler.inverse_transform(y_train)
y_test_actual = scaler.inverse_transform(y_test)
y_pred_actual = scaler.inverse_transform(y_pred)

plt.figure(figsize=(18, 7))

train_size = len(y_train_actual)

plt.plot(np.arange(train_size), y_train_actual[:, 0], label='Train Tesla Close', color='blue', linewidth=2)

plt.plot(np.arange(train_size, train_size + len(y_test_actual)), y_test_actual[:, 0], label='Test Tesla Close', color='black', linestyle='dashed')
plt.plot(np.arange(train_size, train_size + len(y_pred_actual)), y_pred_actual[:, 0], label='Predicted Tesla Close', color='orange', linestyle='dotted')

plt.title('Train, Test and Prediction Tesla')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

errors = {}

rmse_tesla = root_mean_squared_error(y_test_actual[:, 0], y_pred_actual[:, 0])
mse_tesla = mean_squared_error(y_test_actual[:, 0], y_pred_actual[:, 0])
mae_tesla = mean_absolute_error(y_test_actual[:, 0], y_pred_actual[:, 0])
r2_tesla = r2_score(y_test_actual[:, 0], y_pred_actual[:, 0])
errors['Tesla'] = {
    'RMSE': rmse_tesla,
    'MSE': mse_tesla,
    'MAE': mae_tesla,
    'R2': r2_tesla
}

print(f"Tesla - MSE: {mse_tesla}, RMSE : {rmse_tesla}, MAE: {mae_tesla}, R2: {r2_tesla}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Tesla - MSE: 196.5368106955062, RMSE : 14.019158701416652, MAE: 10.008434729609927, R2: 0.8071925312240295

# %%
plt.figure(figsize=(18, 7))

train_size = len(y_train_actual)

plt.plot(np.arange(train_size), y_train_actual[:, 1], label='Train Ford Close', color='blue', linewidth=2)

plt.plot(np.arange(train_size, train_size + len(y_test_actual)), y_test_actual[:, 1], label='Test Ford Close', color='black', linestyle='dashed')
plt.plot(np.arange(train_size, train_size + len(y_pred_actual)), y_pred_actual[:, 1], label='Predicted Ford Close', color='orange', linestyle='dotted')

plt.title('Train, Test and Prediction Ford')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

rmse_ford = root_mean_squared_error(y_test_actual[:, 1], y_pred_actual[:, 1])
mse_ford = mean_squared_error(y_test_actual[:, 1], y_pred_actual[:, 1])
mae_ford = mean_absolute_error(y_test_actual[:, 1], y_pred_actual[:, 1])
r2_ford = r2_score(y_test_actual[:, 1], y_pred_actual[:, 1])

errors['Ford'] = {
    'RMSE': rmse_ford,
    'MSE': mse_ford,
    'MAE': mae_ford,
    'R2': r2_ford
}

print(f"Ford - MSE: {mse_ford}, RMSE : {rmse_ford}, MAE: {mae_ford}, R2: {r2_ford}")
# Out:
# Ford - MSE: 0.39881761352546163, RMSE : 0.6315200816486057, MAE: 0.47585097184417935, R2: 0.662472029711014

# %%
plt.figure(figsize=(18, 7))

train_size = len(y_train_actual)

plt.plot(np.arange(train_size), y_train_actual[:, 2], label='Train BMW Close', color='blue', linewidth=2)

plt.plot(np.arange(train_size, train_size + len(y_test_actual)), y_test_actual[:, 2], label='Test BMW Close', color='black', linestyle='dashed')
plt.plot(np.arange(train_size, train_size + len(y_pred_actual)), y_pred_actual[:, 2], label='Predicted BMW Close', color='orange', linestyle='dotted')

plt.title('Train, Test and Prediction BMW')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

rmse_bmw = root_mean_squared_error(y_test_actual[:, 2], y_pred_actual[:, 2])
mse_bmw = mean_squared_error(y_test_actual[:, 2], y_pred_actual[:, 2])
mae_bmw = mean_absolute_error(y_test_actual[:, 2], y_pred_actual[:, 2])
r2_bmw = r2_score(y_test_actual[:, 2], y_pred_actual[:, 2])

errors['BMW'] = {
    'RMSE': rmse_bmw,
    'MSE': mse_bmw,
    'MAE': mae_bmw,
    'R2': r2_bmw
}

print(f"BMW - MSE: {mse_bmw}, RMSE : {rmse_bmw}, MAE: {mae_bmw}, R2: {r2_bmw}")
# Out:
# BMW - MSE: 0.829709166077669, RMSE : 0.9108837280782158, MAE: 0.6725333372075506, R2: 0.9291194810779465

# %%
plt.figure(figsize=(18, 7))

train_size = len(y_train_actual)

plt.plot(np.arange(train_size), y_train_actual[:, 3], label='Train Volkswagen Close', color='blue', linewidth=2)

plt.plot(np.arange(train_size, train_size + len(y_test_actual)), y_test_actual[:, 3], label='Test Volkswagen Close', color='black', linestyle='dashed')
plt.plot(np.arange(train_size, train_size + len(y_pred_actual)), y_pred_actual[:, 3], label='Predicted Volkswagen Close', color='orange', linestyle='dotted')

plt.title('Train, Test and Prediction Volkswagen')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

rmse_volkswagen = root_mean_squared_error(y_test_actual[:, 3], y_pred_actual[:, 3])
mse_volkswagen = mean_squared_error(y_test_actual[:, 3], y_pred_actual[:, 3])
mae_volkswagen = mean_absolute_error(y_test_actual[:, 3], y_pred_actual[:, 3])
r2_volkswagen = r2_score(y_test_actual[:, 3], y_pred_actual[:, 3])

errors['Volkswagen'] = {
    'RMSE': rmse_volkswagen,
    'MSE': mse_volkswagen,
    'MAE': mae_volkswagen,
    'R2': r2_volkswagen
}
print(f"Volkswagen - MSE: {mse_volkswagen}, RMSE : {rmse_volkswagen}, MAE: {mae_volkswagen}, R2: {r2_volkswagen}")
# Out:
# Volkswagen - MSE: 1.0582007673082598, RMSE : 1.0286888583572098, MAE: 0.9142330699947708, R2: 0.6209439553218477

# %%
plt.figure(figsize=(18, 7))

train_size = len(y_train_actual)

plt.plot(np.arange(train_size), y_train_actual[:, 4], label='Train Hyundai Close', color='blue', linewidth=2)

plt.plot(np.arange(train_size, train_size + len(y_test_actual)), y_test_actual[:, 4], label='Test Hyundai Close', color='black', linestyle='dashed')
plt.plot(np.arange(train_size, train_size + len(y_pred_actual)), y_pred_actual[:, 4], label='Predicted Hyundai Close', color='orange', linestyle='dotted')

plt.title('Train, Test and Prediction Hyundai')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

rmse_hyundai = root_mean_squared_error(y_test_actual[:, 4], y_pred_actual[:, 4])
mse_hyundai = mean_squared_error(y_test_actual[:, 4], y_pred_actual[:, 4])
mae_hyundai = mean_absolute_error(y_test_actual[:, 4], y_pred_actual[:, 4])
r2_hyundai = r2_score(y_test_actual[:, 4], y_pred_actual[:, 4])

errors['Hyundai'] = {
    'RMSE': rmse_hyundai,
    'MSE': mse_hyundai,
    'MAE': mae_hyundai,
    'R2': r2_hyundai
}

print(f"Hyundai - MSE: {mse_hyundai}, RMSE : {rmse_hyundai}, MAE: {mae_hyundai}, R2: {r2_hyundai}")
# Out:
# Hyundai - MSE: 8.434192285873669, RMSE : 2.9041680884331864, MAE: 2.242055936772773, R2: 0.3749157529113498

# %%
companies = list(errors.keys())
metrics = ['RMSE', 'MSE', 'MAE', 'R2']
errors_values = {metric: [errors[company][metric] for company in companies] for metric in metrics}

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.bar(companies, errors_values['RMSE'], color='skyblue')
plt.title('Root Mean Squared Error (RMSE)')
plt.ylabel('RMSE')

plt.subplot(2, 2, 2)
plt.bar(companies, errors_values['MSE'], color='lightgreen')
plt.title('Mean Squared Error (MSE)')
plt.ylabel('MSE')

plt.subplot(2, 2, 3)
plt.bar(companies, errors_values['MAE'], color='lightcoral')
plt.title('Mean Absolute Error (MAE)')
plt.ylabel('MAE')

plt.subplot(2, 2, 4)
plt.bar(companies, errors_values['R2'], color='red')
plt.title('R2 Score')
plt.ylabel('R2')

plt.tight_layout()
plt.show()
